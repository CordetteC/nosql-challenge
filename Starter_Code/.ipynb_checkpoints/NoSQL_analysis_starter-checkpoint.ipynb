# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Use count_documents to display the number of documents in the result
# Display the first document in the results using pprint
pprint(establishments.count_documents(query))
# Out:
# 41

# %%
# Convert the result to a Pandas DataFrame
results = establishments.find(query)
df = pd.DataFrame(list(results))

# Display the number of rows in the DataFrame
num_rows = df.count().iloc[0] 
print("Number of rows in the DataFrame:", num_rows)
# Out:
# Number of rows in the DataFrame: 41

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  678ef5bc3d5b86447dd9b339   110681                  0
# 1  678ef5bc3d5b86447dd9b6b9   612039                  0
# 2  678ef5bc3d5b86447dd9b9c5   730933                  0
# 3  678ef5bc3d5b86447dd9bbb7   172735                  0
# 4  678ef5bc3d5b86447dd9bbbf   172953                  0
# 5  678ef5bc3d5b86447dd9c560   512854                  0
# 6  678ef5bc3d5b86447dd9c782  1537089                  0
# 7  678ef5bc3d5b86447dd9dcac   155648                  0
# 8  678ef5bc3d5b86447dd9e0ee  1012883                  0
# 9  678ef5bc3d5b86447dd9e8f6   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4. 
query = {
    "LocalAuthorityName": {'$regex':"London"},
    "RatingValue": {"$gte": 4}
}
# Use count_documents to display the number of documents in the result
pprint(establishments.count_documents(query))
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# 33
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('678ef5bc3d5b86447dd9cd4e'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Convert the result to a Pandas DataFrame
results = establishments.find(query)
df = pd.DataFrame(list(results))

# Display the number of rows in the DataFrame
num_rows = df.count().iloc[0]  # Counts non-null entries in the first column
print("Number of rows in the DataFrame:", num_rows)# Convert the result to a Pandas DataFrame
# Out:
# Number of rows in the DataFrame: 35

# %%
# Display the first 10 rows of the DataFrame
df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  678ef5bc3d5b86447dd9cb08   783921                  0
# 1  678ef5bc3d5b86447dd9cb5c   510152                  0
# 2  678ef5bc3d5b86447dd9cb5d  1423359                  0
# 3  678ef5bc3d5b86447dd9cb5f   802088                  0
# 4  678ef5bc3d5b86447dd9cb64   786158                  0
# 5  678ef5bc3d5b86447dd9cbc6   783911                  0
# 6  678ef5bc3d5b86447dd9cbcd   605582                  0
# 7  678ef5bc3d5b86447dd9cbe1  1079636                  0
# 8  678ef5bc3d5b86447dd9cc1e   683394                  0
# 9  678ef5bc3d5b86447dd9cc36   802068                  0
#
#   LocalAuthorityBusinessID             BusinessName            BusinessType  \
# 0             PI/000030119                    Co-Op       Retailers - other
# 1             PI/000243002             The Huntsman       Pub/bar/nightclub
# 2              21/00411/CP    Que & Brew Smokehouse  Takeaway/sandwich shop
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.369321
longitude = 0.508551

query = {'geocode.latitude':{"$gte":latitude-degree_search, "$lte":latitude+degree_search},
        'geocode.longitude':{"$gte":longitude-degree_search, "$lte":longitude+degree_search},
        'RatingValue':5}
sort = [('score.Hygiene',1)]
limit = 5

# Print the results
pprint(list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# [{'AddressLine1': '108 Pattens Lane',
#   'AddressLine2': 'Rochester',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Sealand Fish And Chips',
#   'BusinessType': 'Takeaway/sandwich shop',
#   'BusinessTypeID': 7844,
#   'ChangesByServerID': 0,
#   'Distance': 4627.071735597095,
#   'FHRSID': 802088,
#   'LocalAuthorityBusinessID': 'PI/000251174',
#   'LocalAuthorityCode': '896',
#   'LocalAuthorityEmailAddress': 'foodandsafety@medway.gov.uk',
#   'LocalAuthorityName': 'Medway',
#   'LocalAuthorityWebSite': 'http://www.medway.gov.uk/',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'ME1 2RA',
#   'RatingDate': '2022-03-01T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('678ef5bc3d5b86447dd9cb5f'),
#   'geocode': {'latitude': Decimal128('51.366737'),
#               'longitude': Decimal128('0.516021')},
# ...

# %%
# Convert result to Pandas DataFrame
top_5 = establishments.find(query)
top_5_df = pd.DataFrame(list(top_5))
top_5_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  678ef5bc3d5b86447dd9cb08   783921                  0
# 1  678ef5bc3d5b86447dd9cb5c   510152                  0
# 2  678ef5bc3d5b86447dd9cb5d  1423359                  0
# 3  678ef5bc3d5b86447dd9cb5f   802088                  0
# 4  678ef5bc3d5b86447dd9cb64   786158                  0
#
#   LocalAuthorityBusinessID            BusinessName            BusinessType  \
# 0             PI/000030119                   Co-Op       Retailers - other
# 1             PI/000243002            The Huntsman       Pub/bar/nightclub
# 2              21/00411/CP   Que & Brew Smokehouse  Takeaway/sandwich shop
# 3             PI/000251174  Sealand Fish And Chips  Takeaway/sandwich shop
# 4             PI/000030142               News Shop       Retailers - other
#
#    BusinessTypeID        AddressLine1      AddressLine2      AddressLine3  \
# 0            4613  27-31 Pattens Lane           Chatham              Kent
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
pipeline = [
    {"$match": {"scores.Hygiene": 0}}, 
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},  
    {"$sort": {"count": -1}},  
]
# Print the number of documents in the result
results = list(establishments.aggregate(pipeline))
print(f"Number of documents in the result: {len(results)}")

# Print the first 10 results
pprint(results[:10])
# Out:
# Number of documents in the result: 55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
hygiene_results = establishments.find(query)
hygiene_df = pd.DataFrame(list(hygiene_results))

# Display the number of rows in the DataFrame
num_rows = hygiene_df.count().iloc[0]  # Counts non-null entries in the first column
print("Number of rows in the DataFrame:", num_rows)# Convert the result to a Pandas DataFrame
# Out:
# Number of rows in the DataFrame: 35

# %%
# Display the first 10 rows of the DataFrame
hygiene_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  678ef5bc3d5b86447dd9cb08   783921                  0
# 1  678ef5bc3d5b86447dd9cb5c   510152                  0
# 2  678ef5bc3d5b86447dd9cb5d  1423359                  0
# 3  678ef5bc3d5b86447dd9cb5f   802088                  0
# 4  678ef5bc3d5b86447dd9cb64   786158                  0
# 5  678ef5bc3d5b86447dd9cbc6   783911                  0
# 6  678ef5bc3d5b86447dd9cbcd   605582                  0
# 7  678ef5bc3d5b86447dd9cbe1  1079636                  0
# 8  678ef5bc3d5b86447dd9cc1e   683394                  0
# 9  678ef5bc3d5b86447dd9cc36   802068                  0
#
#   LocalAuthorityBusinessID             BusinessName            BusinessType  \
# 0             PI/000030119                    Co-Op       Retailers - other
# 1             PI/000243002             The Huntsman       Pub/bar/nightclub
# 2              21/00411/CP    Que & Brew Smokehouse  Takeaway/sandwich shop
# ...
